# %%
import seaborn as sns
import pandas as pd

# %%
df_iris = sns.load_dataset('iris')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
type(df_iris)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.
#
#     print the first 3 rows
#     print the number of rows and columns (shape)
#     print the column names
#     print the data type of each column
#     print the summary statistics for each of the numeric variables

# %%
df_iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
#get shape
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.columns.to_list()
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
#get datatypes of numerical variables
df_iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
#get summary statistics 
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# jemison_spreadsheet_exercises - RDS.xlsx
# https://docs.google.com/spreadsheets/d/1K0OgiT3FoTywCzvk9ethOAxlvLBYHhGbt0kEFuasQIU/edit#gid=1023018493

# %% [markdown]
# # Specific to google sheets only
# sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'
#
# csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
#b/c google sheets is wonky, from url can turn to csv 
goog_sheet_url = 'https://docs.google.com/spreadsheets/d/1K0OgiT3FoTywCzvk9ethOAxlvLBYHhGbt0kEFuasQIU/edit#gid=1023018493'

csv_export_url = goog_sheet_url.replace('/edit#gid=', '/export?format=csv&gid=') #changes formatting

df_goog_sheet = pd.read_csv(csv_export_url)
df_goog_sheet.head()
print(csv_export_url)
# Out:
# https://docs.google.com/spreadsheets/d/1K0OgiT3FoTywCzvk9ethOAxlvLBYHhGbt0kEFuasQIU/export?format=csv&gid=1023018493

# %%
df_ggle_sheets = pd.read_excel('telco_churn.xlsx')
df_ggle_sheets.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                0.0     Yes        Yes            1.0
# 1  0003-MKNFE    Male                0.0      No         No            2.0
# 2  0004-TLHLJ    Male                0.0      No         No            1.0
# 3  0011-IGKFF    Male                1.0     Yes         No            1.0
# 4  0013-EXCHZ  Female                1.0     Yes         No            1.0
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0               1.0            1.0      Mailed check             65.6
# 1               1.0            0.0      Mailed check             59.9
# 2               2.0            0.0  Electronic check             73.9
# 3               2.0            0.0  Electronic check             98.0
# 4               2.0            0.0      Mailed check             83.9
#
#    total_charges churn     tenure
# 0         593.30    No   9.044207
# ...

# %% [markdown]
# Read the Table1_CustDetails table from your spreadsheet exercises google sheet into a dataframe named df_google_sheets.
#
# Make sure that the spreadsheet is publicly visible under your sharing settings.
#
#     assign the first 100 rows to a new dataframe, df_google_sheets_sample
#     print the number of rows of your original dataframe
#     print the first 5 column names
#     print the column names that have a data type of object
#     compute the range for each of the numeric variables.

# %%
df_google_sheets = pd.read_csv('telco_churn.csv')
df_google_sheets.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#assign the first 100 rows to a new dataframe, df_google_sheets_sample

df_google_sheets_sample = df_google_sheets.head(100)

# %%
#print the number of rows of your original dataframe

len(df_google_sheets)
# Out:
# 7043

# %%
#print the first 5 column names

df_google_sheets.columns[0:5] #use column attribute
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents'], dtype='object')

# %%
#print the column names that have a data type of object
list(df_google_sheets.select_dtypes(['object']).columns)
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
#compute the range for each of the numeric variables

df_google_sheets.select_dtypes('number') #get columns w/ numberic variables

#can use a lambda function
df_google_sheets.select_dtypes('number').apply(lambda c: c.max() - c.min())
# Out:
# SeniorCitizen        1.0
# tenure              72.0
# MonthlyCharges     100.5
# TotalCharges      8666.0
# dtype: float64

# %% [markdown]
# Download your spreadsheet exercises google sheet as an excel file (File → Download → Microsoft Excel). Read the Table1_CustDetails worksheet into a dataframe named df_excel.
#
#     assign the first 100 rows to a new dataframe, df_excel_sample
#     print the number of rows of your original dataframe
#     print the first 5 column names
#     print the column names that have a data type of object
#     compute the range for each of the numeric variables.

# %%
df_excel = pd.read_excel('telco_churn.xlsx', sheet_name = 'Table1_CustDetails')
df_excel.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                0.0     Yes        Yes            1.0
# 1  0003-MKNFE    Male                0.0      No         No            2.0
# 2  0004-TLHLJ    Male                0.0      No         No            1.0
# 3  0011-IGKFF    Male                1.0     Yes         No            1.0
# 4  0013-EXCHZ  Female                1.0     Yes         No            1.0
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0               1.0            1.0      Mailed check             65.6
# 1               1.0            0.0      Mailed check             59.9
# 2               2.0            0.0  Electronic check             73.9
# 3               2.0            0.0  Electronic check             98.0
# 4               2.0            0.0      Mailed check             83.9
#
#    total_charges churn     tenure
# 0         593.30    No   9.044207
# ...

# %%
df_excel_sample = df_excel.head(100)

# %%
len(df_excel)
# Out:
# 7049

# %%
df_excel.columns[0:5]
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %%
df_excel.select_dtypes('object').columns.to_list()
# Out:
# ['customer_id', 'gender', 'partner', 'dependents', 'payment_type', 'churn']

# %%
df_excel.select_dtypes('number').apply(lambda c: c.max() - c.min())
# Out:
# is_senior_citizen       1.000000
# phone_service           2.000000
# internet_service        2.000000
# contract_type           2.000000
# monthly_charges       100.500000
# total_charges        8666.000000
# tenure                 79.341772
# dtype: float64

# %% [markdown]
# Read the data from this google sheet into a dataframe, df_google.
#
#     print the first 3 rows
#     print the number of rows and columns
#     print the column names
#     print the data type of each column
#     print the summary statistics for each of the numeric variables
#     print the unique values for each of your categorical variables

# %%
#b/c google sheets is wonky, from url can turn to csv 
goog_sheet_url = 'https://docs.google.com/spreadsheets/d/1K0OgiT3FoTywCzvk9ethOAxlvLBYHhGbt0kEFuasQIU/edit#gid=1023018493'

csv_export_url = goog_sheet_url.replace('/edit#gid=', '/export?format=csv&gid=') #changes formatting

df_google = pd.read_csv(csv_export_url)
df_google.head(3)
#print(csv_export_url)
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0                 1              1      Mailed check             65.6
# 1                 1              0      Mailed check             59.9
# 2                 2              0  Electronic check             73.9
#
#    total_charges churn  tenure
# 0         593.30    No     9.0
# 1         542.40    No     9.1
# 2         280.85   Yes     3.8

# %%
df_google.shape
# Out:
# (7049, 13)

# %%
df_google.columns.to_list()
# Out:
# ['customer_id',
#  'gender',
#  'is_senior_citizen',
#  'partner',
#  'dependents',
#  'phone_service',
#  'internet_service',
#  'contract_type',
#  'payment_type',
#  'monthly_charges',
#  'total_charges',
#  'churn',
#  'tenure']

# %%
df_google.dtypes
# Out:
# customer_id           object
# gender                object
# is_senior_citizen      int64
# partner               object
# dependents            object
# phone_service          int64
# internet_service       int64
# contract_type          int64
# payment_type          object
# monthly_charges      float64
# total_charges        float64
# churn                 object
# tenure               float64
# dtype: object

# %%
df_excel.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges       tenure
# count      7049.000000    7038.000000  7049.000000
# mean         64.747014    2283.043883    32.379866
# std          30.099460    2266.521984    24.595524
# min          18.250000      18.800000     0.000000
# 25%          35.450000     401.587500     8.733456
# ...

# %%
#print the unique values for each of your categorical variables

for item in df_excel.select_dtypes('object').columns:
    print(item)
    print(df_excel[item].unique())
# Out:
# customer_id
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# gender
# ['Female' 'Male']
# partner
# ['Yes' 'No']
# dependents
# ['Yes' 'No']
# payment_type
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# churn
# ['No' 'Yes']

# %%
#alternative: lambda to get unique values:

df_google.select_dtypes('object').apply(lambda c: c.unique().tolist()) #an array, so use tolist()
# Out:
# customer_id     [0002-ORFBO, 0003-MKNFE, 0004-TLHLJ, 0011-IGKF...
# gender                                             [Female, Male]
# partner                                                 [Yes, No]
# dependents                                              [Yes, No]
# payment_type    [Mailed check, Electronic check, Credit card (...
# churn                                                   [No, Yes]
# dtype: object

# %% [markdown]
# Make a new python module, acquire.py to hold the following data aquisition functions:
#
#     Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database (they mean the CodeUp SQL DB we've been using).
#
#     Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database (SQL DB).
#
#     Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join all 4 tables together, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database (SQL DB).
#
#     Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
from acquire import get_titanic_data

# %%
#Make a function, stored in acquire.py : get_titanic_data
df = get_titanic_data()
df.head()
# Out:
#    Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
# 2           2             2         1       3  female  26.0      0      0
# 3           3             3         1       1  female  35.0      1      0
# 4           4             4         0       3    male  35.0      0      0
#
#       fare embarked  class deck  embark_town  alone
# 0   7.2500        S  Third  NaN  Southampton      0
# 1  71.2833        C  First    C    Cherbourg      0
# 2   7.9250        S  Third  NaN  Southampton      1
# 3  53.1000        S  First    C  Southampton      0
# 4   8.0500        S  Third  NaN  Southampton      1

# %%
from acquire import get_iris_data

#df = get_iris_data()
#df.head()

# %%
from acquire import get_telco_data

df = get_telco_data()
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
